# %%
import os
import keras
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
model = keras.applications.VGG16(weights='imagenet', include_top=True)
# Out:
# WARNING:tensorflow:From /Users/dorothy/miniconda3/envs/dorothy/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
# !ls ../image/256px_image_square_final
# Out:
# adélie_penguin             light_bulb
# aluminum_can               lion
# banana                     lizard
# barley                     long_distance_migrant_bird
# bumblebee                  mason_bee
# cacao                      newt
# carpenter_bee              phytoplankton
# china_wheat                plastic_bag
# coffee                     plastic_beverage_holder
# coral                      plastic_bottle
# corn                       polar_bear
# crocodilian                quiver_tree
# disposable_diaper          shark
# electronic_waste           snake
# fishing_line               snowy_plover
# forest_bird                spring_peeper
# frog                       spruce_budworm
# gecko                      styrofoam
# glass_bottle               styrofoam_buoy
# ink_cartridge              tiger
# ivory_gull                 tin_can
# jack_pine_budworm          toad
# korean_rice

# %%
import numpy as np
import matplotlib.pyplot as plt

def load_image(path):
    img = image.load_img(path, target_size=model.input_shape[1:3])
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
img, x = load_image("../image/256px_image_square_final/adélie_penguin/4_7_1_1.jpg")
print("shape of X: ", x.shape)
print("data type: ", x.dtype)
plt.imshow(img)
# Out:
# shape of X:  (1, 224, 224, 3)
# data type:  float32

# %%
predictions = model.predict(x)

for _, pred, prob in decode_predictions(predictions)[0]:
    print("predicted %s with probability %0.3f" % (pred, prob))
# Out:
# predicted king_penguin with probability 1.000
# predicted goose with probability 0.000
# predicted weasel with probability 0.000
# predicted quail with probability 0.000
# predicted guenon with probability 0.000

# %% [markdown]
# ## Feature Extraction

# %%
feat_extractor = Model(inputs=model.input, outputs=model.get_layer("fc2").output)
feat_extractor.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
img, x = load_image("../image/256px_image_square_final/adélie_penguin/4_7_1_1.jpg")
feat = feat_extractor.predict(x)

plt.figure(figsize=(16, 4))
plt.plot(feat[0])

# %%
images_path = '.'
image_extensions = ['.jpg']
max_num_images = 6855

images = [os.path.split(os.path.join(dp, f))[0] for dp, dn, filenames in os.walk(images_path) for f in filenames 
          if os.path.splitext(f)[1].lower() in image_extensions]


print(images)

if max_num_images < len(images):
    images = [images[i] for i in sorted(random.sample(xrange(len(images)), max_num_images))]
    
print("keeping %d images to analyze" % len(images))
# Out:
# []
# keeping 0 images to analyze

# %%
import time
tic = time.clock()

features = []

for i, image_path in enumerate(images):
    if i%500 == 0:
        toc = time.clock()
        elap = toc - tic;
        print("analyzing image %d / %d. Time: %4.4f seconds." % (i, len(images), elap))
        tic = time.clock()
    img, x = load_image(image_path)
    feat = feat_extractor.predict(x)[0]
    features.append(feat)
    
print('finished extracting features for %d images' % len(images))
# Out:
# analyzing image 0 / 6855. Time: 0.0001 seconds.
# analyzing image 500 / 6855. Time: 718.1450 seconds.
# analyzing image 1000 / 6855. Time: 720.3638 seconds.
# analyzing image 1500 / 6855. Time: 724.6007 seconds.
# analyzing image 2000 / 6855. Time: 723.1732 seconds.
# analyzing image 2500 / 6855. Time: 726.8306 seconds.
# analyzing image 3000 / 6855. Time: 729.8062 seconds.
# analyzing image 3500 / 6855. Time: 727.1062 seconds.
# analyzing image 4000 / 6855. Time: 726.9800 seconds.
# analyzing image 4500 / 6855. Time: 723.8073 seconds.
# analyzing image 5000 / 6855. Time: 723.5636 seconds.
# analyzing image 5500 / 6855. Time: 724.6485 seconds.
# analyzing image 6000 / 6855. Time: 721.5215 seconds.
# analyzing image 6500 / 6855. Time: 720.7104 seconds.
# finished extracting features for 6855 images

# %%
from sklearn.decomposition import PCA

features = np.array(features)
pca = PCA(n_components=300)
pca.fit(features)
print(pca)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=300, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca_features = pca.transform(features)
print(len(pca_features))
# Out:
# 6855

# %%
import random

query_image_idx = int(len(images) * random.random())

img = image.load_img(images[query_image_idx])
plt.imshow(img)

# %%
from scipy.spatial import distance

similar_idx = [distance.cosine(pca_features[query_image_idx], feat) for feat in pca_features]

# %%
idx_closest = sorted(range(len(similar_idx)), key=lambda k: similar_idx[k])[1:6]

# %%
thumbs = []

for idx in idx_closest:
    img = image.load_img(images[idx])
    img = img.resize((int(img.width*100 / img.height), 100))
    thumbs.append(img)
    
concat_image = np.concatenate([np.asarray(t) for t in thumbs], axis=1)

plt.figure(figsize=(16, 12))
plt.imshow(concat_image)

# %%
import pickle

pickle.dump([images, pca_features, pca], open('../data/128px/features_128px_image_square_final.p', 'wb'))

# %%
images, pca_features, pca = pickle.load(open('../data/128px/features_128px_image_square_final.p', 'rb'))

for img, f in list(zip(images, pca_features))[0:5]:
    print("image: %s, features: %0.2f, %0.2f, %0.2f, %0.2f..." % (img, f[0], f[1], f[2], f[3]))
    
print(len(pca_features))
print(len(images))
# Out:
# image: ../image/256px_image_square_final/jack_pine_budworm/1_2_2_2.jpg, features: 11.69, -6.00, 6.13, -12.13...
# image: ../image/256px_image_square_final/jack_pine_budworm/1_2_2_3.jpg, features: -3.17, -10.32, 8.20, -8.92...
# image: ../image/256px_image_square_final/jack_pine_budworm/1_2_2_1.jpg, features: 3.52, -8.32, 1.88, -19.63...
# image: ../image/256px_image_square_final/jack_pine_budworm/1_2_2_4.jpg, features: -7.97, -2.63, -0.51, -11.17...
# image: ../image/256px_image_square_final/jack_pine_budworm/1_2_2_5.jpg, features: 2.05, -18.71, 14.11, -9.39...
# 6855
# 6855
